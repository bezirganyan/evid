# %%
from model.model_viz import Visualizer
from model.model import EpiModel
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Experiment 1

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0,
    'inf_radius' : 0.7,
    'healing_period' : np.inf,
    'travel_prob' : 0,
    'healthcare_potential' : 0,
    'n_boxes': 0,
    'travel_dist_factor': 1,
    'travel_to_point_prob': 0}
model = EpiModel(**args)
vis = Visualizer(model)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 2

# %% [markdown]
# Add death probability and healing period

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.07,
    'inf_radius' : 0.7,
    'healing_period' : 7,
    'travel_prob' : 0,
    'healthcare_potential' : 0,
    'n_boxes': 0}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 2.5

# %% [markdown]
# add healthcare limit

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.07,
    'inf_radius' : 0.7,
    'healing_period' : 7,
    'travel_prob' : 0,
    'healthcare_potential' : 0.2,
    'n_boxes': 0}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 3

# %% [markdown]
# Travel more

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.07,
    'inf_radius' : 0.8,
    'healing_period' : 7,
    'travel_prob' : 0,
    'healthcare_potential' : 0.2,
    'n_boxes': 0,
    'travel_dist_factor': 3}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# Less travelling

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.07,
    'inf_radius' : 0.7,
    'healing_period' : 7,
    'travel_prob' : 0,
    'healthcare_potential' : 0.2,
    'n_boxes': 0,
    'travel_dist_factor': 0.3}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 5

# %% [markdown]
# Keep social Distance

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.07,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 6

# %% [markdown]
# add travel prob

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.04,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0.2,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 7

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.04,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0.5,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 8

# %% [markdown]
# central market

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.04,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0.2,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1,
    'travel_to_point_prob': 0.05}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Experiment 8

# %% [markdown]
# add quaranteen

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.04,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0.2,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1,
    'travel_to_point_prob': 0.05,
    'quaranteen_after': 2,
    'quaranteen_strictness': 1}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
args = {
    'population_number' : 1000,
    'width' : 10,
    'height' : 10,
    'transmission_prob' : 0.2,
    'mortality_rate' : 0.04,
    'inf_radius' : 0.3,
    'healing_period' : 7,
    'travel_prob' : 0.2,
    'healthcare_potential' : 0.2,
    'n_boxes': 10,
    'travel_dist_factor': 1,
    'travel_to_point_prob': 0.05,
    'quaranteen_after': 2,
    'quaranteen_strictness': 0.8}
model_1 = EpiModel(**args)
vis = Visualizer(model_1)
vis.create_animation(frame_per_step=5)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">
